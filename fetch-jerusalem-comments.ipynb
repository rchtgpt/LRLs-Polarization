# %%
import requests
import json
from datetime import date, timedelta

url = 'https://open.tiktokapis.com/v2/research/video/query/?fields=id,video_description,create_time,region_code,share_count,view_count,like_count,comment_count,hashtag_names,username,voice_to_text'

# A new bearer token needs to be generated every 2 hours

headers = {
    'authorization': 'bearer clt.DjLyPCEEmaCEs9qWPAbYCtxFR6boQy48dAhqL5fGXIsiRrXnkgWLnGBjzY7W',
    'Content-Type': 'application/json',
}

final_json = []
username_vidID_pair = {}

date_val = date(2024, 4, 1)
todays_date = date.today()

while (date_val < date(2024, 4, 3)):
    prev_cursor = -1
    cursor = 0
    search_id = ""

    current_date_vids = []

    while (prev_cursor != cursor and cursor < 250): 
        print("the value of cursor being fed into the query", cursor)

        current_date = date_val.strftime("%Y%m%d")

        data = {
            "query": {
                "and": [
                    {"operation": "IN", "field_name": "hashtag_name", "field_values": ["ירושלים"]}, # ירושלים means jerusalem 
                ]
            },
            "cursor": cursor,
            "search_id": search_id,
            "start_date": current_date,
            "end_date": current_date,
            "is_random": False 
        }
        
        response = requests.post(url, headers=headers, json=data)
        json_data = response.json()

        if 'data' in json_data and 'videos' in json_data['data']:
            for video in json_data['data']['videos']:
                 if video["comment_count"] > 20:   
                    print(video["id"])
                    print(type(video["id"]))
                    # # current_date_vids.append(video)
                    # comments_url = 'https://open.tiktokapis.com/v2/research/video/comment/list/?fields=text'
                    # # comments_data = {
                    # #     "video_id": video["id"],
                    # #     "max_count": 100,
                    # #     "cursor": 200
                    # # }

                    # comments_data = {
                    #     "video_id": 7178997441201524010,
                    #     "max_count": 50,
                    #     "cursor": 150
                    # }
                    
                    # comments_response = requests.post(comments_url, headers=headers, json=comments_data)
                    # comments_json_data = comments_response.json()
                    # print(comments_json_data)

            # print(current_date_vids)
            prev_cursor = cursor
            cursor = json_data['data'].get('cursor', -1)
            search_id = json_data['data'].get('search_id', "")

        else:
            print("hi", json_data)
            print("No 'data' key found in the response JSON.")
            break

    for video in current_date_vids:
        print(current_date_vids)
        username_vidID_pair[video["id"]] = video["username"]

#     # Write the JSON data to a new file
#     final_json.append({
#                     "date": date_val.strftime("%Y%m%d"), 
#                     "value": {
#                         "has_more": json_data['data'].get('has_more', False), 
#                         "videos": current_date_vids, 
#                         "cursor": cursor
#                         }
#                 })

#     date_val += timedelta(days=1)
#     print("new date to be explored is", date_val)

# with open('hebrew-jerusalem-comments-data.json', 'a', encoding='utf-8') as json_file:
#         json.dump(final_json, 
#                 json_file, 
#                 indent=2, 
#                 ensure_ascii=False
#             )
# Out:
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212320A2B4129BA077C7308553'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123205C352DB22F43133A7591'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '2024042721232011F59E640BEC3B354307'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212320361FEDBCB02CC731664F'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123215C352DB22F43133A75A3'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123211DCA0C005A0A49348A29'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212321BD817B32091BA035B9C9'}, 'data': {}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123215C352DB22F43133A75BD'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123215C352DB22F43133A75C1'}, 'data': {}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212326E3A2E586DA247730A818'}, 'data': {}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '2024042721232796F201728BEFFB3B0D19'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212327A2B4129BA077C730867C'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212327DF40922CA937EB35499A'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212327B9C5EE7CD44A3B345A31'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '202404272123275C352DB22F43133A76D5'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212327A2B4129BA077C7308693'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212328AE2B1CA5772AA93A03CF'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212329B9C5EE7CD44A3B345A71'}, 'data': {}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212329DF40922CA937EB3549C9'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212329A2B4129BA077C73086C6'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '20240427212329EDC67467C510493A6414'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
# hi {'data': {}, 'error': {'code': 'daily_quota_limit_exceeded', 'message': 'The API daily quota limit exceeded. Please try again later', 'log_id': '2024042721232934A6007FC3E23930D284'}}
# No 'data' key found in the response JSON.
# the value of cursor being fed into the query 0
