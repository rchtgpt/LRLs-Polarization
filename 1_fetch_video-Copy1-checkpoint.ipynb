# %%
# IMPORTS

import requests
import json
from datetime import date, timedelta

# %% [markdown]
# # Fetch Video Data

# %%
# Defining endpoint for accessing TikTok's API

url = 'https://open.tiktokapis.com/v2/research/video/query/?fields=id,video_description,create_time,region_code,share_count,view_count,like_count,comment_count,hashtag_names,username,voice_to_text'

# %%
# TODO: Define a new bearer token. Refer to Dev Documentation to see how to generate a new bearer token. 
# NOTE: The bearer token expires every 2 hours.

headers = {
    'authorization': 'bearer clt.PgF9ykNC0nHovOqFo0sEq0VbAqFIDQdcwKmbPm6KhfEJmd3OV91ufA99YHjo',
    'Content-Type': 'application/json',
}

# %%
# Fetch all video details

final_json = []
username_vidID_pair = {}

date_val = date(2023, 10, 7)
todays_date = date.today()

while (date_val < date(2023, 10, 9)):
    prev_cursor = -1
    cursor = 0
    search_id = ""

    current_date_vids = []

    while (prev_cursor != cursor): 
        print("the value of cursor being fed into the query", cursor)

        current_date = date_val.strftime("%Y%m%d")

        data = {
            "query": {
                "and": [
                    {"operation": "IN", "field_name": "hashtag_name", "field_values": ["עזה"]}, # עזה means gaza 
                ]
            },
            "cursor": cursor,
            "search_id": search_id,
            "start_date": current_date,
            "end_date": current_date,
            "is_random": False 
        }
        
        response = requests.post(url, headers=headers, json=data)
        json_data = response.json()

        if 'data' in json_data and 'videos' in json_data['data']:
            current_date_vids.extend(json_data['data']['videos'])
            prev_cursor = cursor
            cursor = json_data['data'].get('cursor', -1)
            search_id = json_data['data'].get('search_id', "")

        else:
            print(json_data)
            print("No 'data' key found in the response JSON.")
            break

    for video in current_date_vids:
        username_vidID_pair[video["id"]] = video["username"]

    # Write the JSON data to a new file
    final_json.append({
                    "date": date_val.strftime("%Y%m%d"), 
                    "value": {
                        "has_more": json_data['data'].get('has_more', False), 
                        "videos": current_date_vids, 
                        "cursor": cursor
                        }
                })

    date_val += timedelta(days=1)
    print("new date to be explored is", date_val)
# Out:
# the value of cursor being fed into the query 0
# the value of cursor being fed into the query 20
# the value of cursor being fed into the query 40
# the value of cursor being fed into the query 60
# the value of cursor being fed into the query 80
# the value of cursor being fed into the query 100
# the value of cursor being fed into the query 120
# the value of cursor being fed into the query 140
# the value of cursor being fed into the query 160
# the value of cursor being fed into the query 180
# the value of cursor being fed into the query 200
# the value of cursor being fed into the query 220
# the value of cursor being fed into the query 240
# the value of cursor being fed into the query 260
# the value of cursor being fed into the query 280
# the value of cursor being fed into the query 298
# new date to be explored is 2023-10-08
# the value of cursor being fed into the query 0
# the value of cursor being fed into the query 20
# the value of cursor being fed into the query 40
# the value of cursor being fed into the query 60
# the value of cursor being fed into the query 80
# the value of cursor being fed into the query 100
# the value of cursor being fed into the query 120
# the value of cursor being fed into the query 140
# the value of cursor being fed into the query 160
# the value of cursor being fed into the query 180
# the value of cursor being fed into the query 200
# the value of cursor being fed into the query 220
# the value of cursor being fed into the query 240
# the value of cursor being fed into the query 260
# the value of cursor being fed into the query 280
# the value of cursor being fed into the query 295
# new date to be explored is 2023-10-09

# %%
with open('hashtag2_filtered.json', 'a', encoding='utf-8') as json_file: # Writes into a separate JSON file
        json.dump(final_json, 
                json_file, 
                indent=2, 
                ensure_ascii=False
            )

# %% [markdown]
# # Concatenate URLs from Video Data Fetched

# %%
def findURLs(username_vidID_pair):
    """
    Using Video IDs and username, we can create the URL ourselves:

    https://www.tiktok.com/@{username}/video/{video_id}
    """
    for video_id, username in username_vidID_pair.items():
        print(f"https://www.tiktok.com/@{username}/video/{video_id}")

# Print all the URLs fetched for the given date range
print(len(username_vidID_pair))
findURLs(username_vidID_pair)
# Out:
# 329
# https://www.tiktok.com/@usertq9k5tebuh/video/7287366349750373634
# https://www.tiktok.com/@badrahimrabzamir/video/7287350409021213953
# https://www.tiktok.com/@user2533813365105/video/7287350403308506376
# https://www.tiktok.com/@mynameismia007/video/7287348937898462471
# https://www.tiktok.com/@liel_631/video/7287348869615144193
# https://www.tiktok.com/@nisofrancis/video/7287343392160255239
# https://www.tiktok.com/@user4533875863391/video/7287343133820554498
# https://www.tiktok.com/@ofaqim_muni/video/7287336880151088386
# https://www.tiktok.com/@amirko80/video/7287335516075347201
# https://www.tiktok.com/@tamiraa133/video/7287332575746559239
# https://www.tiktok.com/@car_mimun/video/7287328790651424007
# https://www.tiktok.com/@focus.il/video/7287327693488557314
# https://www.tiktok.com/@scoop1news/video/7287322393763237127
# https://www.tiktok.com/@zalmanstub/video/7287321942682569991
# https://www.tiktok.com/@sportstoress/video/7287320871977422082
# https://www.tiktok.com/@yaniv_abutbool/video/7287319786445376769
# https://www.tiktok.com/@neymarjreverybody12/video/7287319262916660488
# https://www.tiktok.com/@i.love.minors_fortnite/video/7287317897599307016
# https://www.tiktok.com/@shiran2500/video/7287317030196268296
# https://www.tiktok.com/@holylandspeaksbackup/video/7287314378347547912
# https://www.tiktok.com/@blox_y9725/video/7287312627200511233
# https://www.tiktok.com/@user2162447954655/video/7287312415597907218
# https://www.tiktok.com/@shma.adonai/video/7287307549001485600
# https://www.tiktok.com/@sisodxuo4g4/video/7287307106682670338
# https://www.tiktok.com/@salmonicki/video/7287304912449309953
# https://www.tiktok.com/@shma.adonai/video/7287303031220210977
# https://www.tiktok.com/@kabtube.co/video/7287302997355302145
# https://www.tiktok.com/@arielidan1414/video/7287302935468379394
# https://www.tiktok.com/@libidancer/video/7287301716935052546
# https://www.tiktok.com/@yiramne/video/7287301525637025026
# https://www.tiktok.com/@putnik7892/video/7287299934821371143
# https://www.tiktok.com/@ariel_hameshooamemet/video/7287299533107727617
# https://www.tiktok.com/@iconicsignzz/video/7287299473695345921
# https://www.tiktok.com/@user6366752663092/video/7287298253169626386
# https://www.tiktok.com/@noamroshmusic/video/7287297677170052353
# https://www.tiktok.com/@inspiration1212/video/7287295960630185223
# https://www.tiktok.com/@shma.adonai/video/7287295244993891616
